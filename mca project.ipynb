# %% [markdown]
# ### Import data set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Crop_recommendation.csv')

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.rename(columns={'N':'Nitrogen','P':'phosphorus','K':'potassium'},inplace=True)

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
df.head()
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      rainfall label
# 0  202.935536  rice
# 1  226.655537  rice
# 2  263.964248  rice
# 3  242.864034  rice
# 4  262.717340  rice

# %%
df.tail()
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 2195  177.774507  coffee
# 2196  127.924610  coffee
# 2197  173.322839  coffee
# 2198  127.175293  coffee
# 2199  140.937041  coffee

# %%
df.describe()
# Out:
#           Nitrogen   phosphorus    potassium  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   phosphorus   2200 non-null   int64
#  2   potassium    2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df['label'].count()
# Out:
# 2200

# %%
df.isnull()
# Out:
#       Nitrogen  phosphorus  potassium  temperature  humidity     ph  rainfall  \
# 0        False       False      False        False     False  False     False
# 1        False       False      False        False     False  False     False
# 2        False       False      False        False     False  False     False
# 3        False       False      False        False     False  False     False
# 4        False       False      False        False     False  False     False
# ...        ...         ...        ...          ...       ...    ...       ...
# 2195     False       False      False        False     False  False     False
# 2196     False       False      False        False     False  False     False
# 2197     False       False      False        False     False  False     False
# 2198     False       False      False        False     False  False     False
# 2199     False       False      False        False     False  False     False
#
#       label
# 0     False
# ...

# %%
df.isnull().sum()
# Out:
# Nitrogen       0
# phosphorus     0
# potassium      0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.count()
# Out:
# Nitrogen       2200
# phosphorus     2200
# potassium      2200
# temperature    2200
# humidity       2200
# ph             2200
# rainfall       2200
# label          2200
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %% [markdown]
# ### splitiing data

# %%
df.columns
# Out:
# Index(['Nitrogen', 'phosphorus', 'potassium', 'temperature', 'humidity', 'ph',
#        'rainfall', 'label'],
#       dtype='object')

# %%
x=df[['Nitrogen', 'phosphorus', 'potassium', 'temperature', 'humidity', 'ph','rainfall']]
x
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall
# 0     202.935536
# 1     226.655537
# 2     263.964248
# 3     242.864034
# ...

# %%
y=df['label']
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %% [markdown]
# ### training and texting data set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 1863         1          12         30    27.754298  95.946438  5.562224
# 987         11          10         45    22.630452  88.455772  6.397996
# 375          5          74         21    16.244692  21.357939  5.591704
# 1071       105          88         54    25.787498  84.511942  6.020445
# 37          95          39         36    23.863305  83.152508  5.561399
# ...        ...         ...        ...          ...        ...       ...
# 960          1          27         36    23.985988  93.342366  5.684995
# 905         31          25         38    24.962732  92.405014  6.497367
# 1096        92          81         52    28.010680  76.528081  5.891414
# 235         28          58         81    17.475010  16.543148  6.180427
# 1061        95          74         50    25.901131  80.471527  6.002482
#
#         rainfall
# 1863  131.090008
# 987   109.035760
# 375    66.970533
# 1071  114.200546
# ...

# %%
x_test
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 1276        25         129        195    17.986678  81.177121  5.777271
# 1446       106          20         51    29.730197  90.970157  6.342573
# 335         33          59         22    22.642369  21.593961  5.947000
# 1458        89           9         47    29.471563  90.770696  6.668383
# 2038        62          49         37    24.217446  82.852840  7.479248
# ...        ...         ...        ...          ...        ...       ...
# 1508        22         144        196    21.911913  91.687481  6.499227
# 1595        40         120        197    23.805938  92.488795  5.889481
# 1032       105          74         45    25.145176  81.382041  6.098369
# 1330       118          15         45    24.214957  84.205770  6.538006
# 1263        37         135        205    11.827682  80.282719  5.510925
#
#         rainfall
# 1276   72.371277
# 1446   20.490356
# 335   122.388601
# 1458   28.752261
# ...

# %%
y_train
# Out:
# 1863        coconut
# 987     pomegranate
# 375     kidneybeans
# 1071         banana
# 37             rice
#            ...
# 960     pomegranate
# 905     pomegranate
# 1096         banana
# 235        chickpea
# 1061         banana
# Name: label, Length: 1760, dtype: object

# %%
y_test
# Out:
# 1276         grapes
# 1446      muskmelon
# 335     kidneybeans
# 1458      muskmelon
# 2038           jute
#            ...
# 1508          apple
# 1595          apple
# 1032         banana
# 1330     watermelon
# 1263         grapes
# Name: label, Length: 440, dtype: object

# %% [markdown]
# ### logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lg.predict(x_test)
# Out:
# array(['grapes', 'muskmelon', 'kidneybeans', 'muskmelon', 'jute',
#        'watermelon', 'kidneybeans', 'orange', 'jute', 'pigeonpeas',
#        'pomegranate', 'jute', 'coffee', 'mango', 'mothbeans', 'banana',
#        'banana', 'coconut', 'banana', 'orange', 'lentil', 'apple',
#        'pomegranate', 'papaya', 'muskmelon', 'banana', 'grapes',
#        'coconut', 'cotton', 'watermelon', 'maize', 'maize', 'muskmelon',
#        'apple', 'mothbeans', 'cotton', 'mango', 'blackgram', 'lentil',
#        'orange', 'pigeonpeas', 'grapes', 'orange', 'papaya', 'coconut',
#        'pomegranate', 'papaya', 'coffee', 'chickpea', 'jute', 'chickpea',
#        'coffee', 'lentil', 'pomegranate', 'coffee', 'mungbean',
#        'watermelon', 'watermelon', 'cotton', 'mango', 'blackgram',
#        'mungbean', 'pomegranate', 'banana', 'coffee', 'muskmelon',
#        'chickpea', 'grapes', 'apple', 'jute', 'grapes', 'mango', 'orange',
#        'maize', 'rice', 'watermelon', 'watermelon', 'maize', 'cotton',
# ...

# %%
lg.predict([[25,129,195,17.986678,81.177121,5.777271,72.371277]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['grapes'], dtype=object)

# %%
lg.score(x_test,y_test)
# Out:
# 0.9704545454545455

# %% [markdown]
# ### Decission tree algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_4=DecisionTreeClassifier()

# %%
model_4.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_4.predict(x_test)
# Out:
# array(['grapes', 'muskmelon', 'kidneybeans', 'muskmelon', 'jute',
#        'watermelon', 'kidneybeans', 'orange', 'jute', 'pigeonpeas',
#        'pomegranate', 'jute', 'coffee', 'mango', 'mothbeans', 'banana',
#        'banana', 'coconut', 'banana', 'orange', 'lentil', 'apple',
#        'pomegranate', 'papaya', 'muskmelon', 'banana', 'grapes',
#        'coconut', 'cotton', 'watermelon', 'maize', 'maize', 'muskmelon',
#        'apple', 'mothbeans', 'cotton', 'mango', 'blackgram', 'mungbean',
#        'orange', 'pigeonpeas', 'grapes', 'orange', 'papaya', 'coconut',
#        'pomegranate', 'papaya', 'coffee', 'chickpea', 'jute', 'chickpea',
#        'maize', 'lentil', 'pomegranate', 'coffee', 'mungbean',
#        'watermelon', 'watermelon', 'cotton', 'mango', 'blackgram',
#        'mungbean', 'pomegranate', 'banana', 'coffee', 'muskmelon',
#        'chickpea', 'grapes', 'apple', 'jute', 'grapes', 'mango', 'orange',
# ...

# %%
model_4.predict([[30,130,100,11.956678,45.100221,5.507271,60.312277]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['blackgram'], dtype=object)

# %%
print('accuracy is==',model_4.score(x_test,y_test))
# Out:
# accuracy is== 0.9954545454545455

# %%
import joblib

# %%
file_name='crop_app'

# %%
joblib.dump(model_4,'crop_app')
# Out:
# ['crop_app']

# %%
apps=joblib.load('crop_app')

# %%
arr=[[25,129,195,17.986678,81.177121,5.777271,72.371277]]
x_predict=apps.predict(arr)
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
x_predict
# Out:
# array(['grapes'], dtype=object)

# %% [markdown]
# ### Random forest algorithm

# %%
from sklearn.ensemble import  RandomForestClassifier

# %%
model1=RandomForestClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model1.predict(x_test)
# Out:
# array(['grapes', 'muskmelon', 'kidneybeans', 'muskmelon', 'jute',
#        'watermelon', 'kidneybeans', 'orange', 'jute', 'pigeonpeas',
#        'pomegranate', 'jute', 'coffee', 'mango', 'mothbeans', 'banana',
#        'banana', 'coconut', 'banana', 'orange', 'lentil', 'apple',
#        'pomegranate', 'papaya', 'muskmelon', 'banana', 'grapes',
#        'coconut', 'cotton', 'watermelon', 'maize', 'maize', 'muskmelon',
#        'apple', 'mothbeans', 'cotton', 'mango', 'blackgram', 'mungbean',
#        'orange', 'pigeonpeas', 'grapes', 'orange', 'papaya', 'coconut',
#        'pomegranate', 'papaya', 'coffee', 'chickpea', 'jute', 'chickpea',
#        'maize', 'lentil', 'pomegranate', 'coffee', 'mungbean',
#        'watermelon', 'watermelon', 'cotton', 'mango', 'blackgram',
#        'mungbean', 'pomegranate', 'banana', 'coffee', 'muskmelon',
#        'chickpea', 'grapes', 'apple', 'jute', 'grapes', 'mango', 'orange',
# ...

# %%
model1.predict([[50,150,200,12.985678,50.171221,8.777271,80.371277]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['grapes'], dtype=object)

# %%
model1.score(x_test,y_test)
# Out:
# 0.9977272727272727

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
model2=SVC(kernel='linear')

# %%
model2.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model2.predict(x_test)
# Out:
# array(['grapes', 'muskmelon', 'kidneybeans', 'muskmelon', 'jute',
#        'watermelon', 'kidneybeans', 'orange', 'jute', 'pigeonpeas',
#        'pomegranate', 'jute', 'coffee', 'mango', 'mothbeans', 'banana',
#        'banana', 'coconut', 'banana', 'orange', 'lentil', 'apple',
#        'pomegranate', 'papaya', 'muskmelon', 'banana', 'grapes',
#        'coconut', 'cotton', 'watermelon', 'maize', 'maize', 'muskmelon',
#        'apple', 'mothbeans', 'cotton', 'mango', 'blackgram', 'mungbean',
#        'orange', 'pigeonpeas', 'grapes', 'orange', 'papaya', 'coconut',
#        'pomegranate', 'papaya', 'coffee', 'chickpea', 'jute', 'chickpea',
#        'maize', 'lentil', 'pomegranate', 'coffee', 'mungbean',
#        'watermelon', 'watermelon', 'cotton', 'mango', 'blackgram',
#        'mungbean', 'pomegranate', 'banana', 'coffee', 'muskmelon',
#        'chickpea', 'grapes', 'apple', 'jute', 'grapes', 'mango', 'orange',
# ...

# %%
model2.predict([[60,120,120,19.985678,49.171221,6.777271,15.371277]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array(['chickpea'], dtype=object)

# %%
model2.score(x_test,y_test)
# Out:
# 0.9886363636363636

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
classifier.predict(x_test)
# Out:
# array(['grapes', 'muskmelon', 'kidneybeans', 'muskmelon', 'jute',
#        'watermelon', 'kidneybeans', 'orange', 'jute', 'pigeonpeas',
#        'pomegranate', 'jute', 'coffee', 'mango', 'mothbeans', 'banana',
#        'banana', 'coconut', 'banana', 'orange', 'lentil', 'apple',
#        'pomegranate', 'papaya', 'muskmelon', 'banana', 'grapes',
#        'coconut', 'cotton', 'watermelon', 'maize', 'maize', 'muskmelon',
#        'apple', 'mothbeans', 'cotton', 'mango', 'blackgram', 'mungbean',
#        'orange', 'pigeonpeas', 'grapes', 'orange', 'papaya', 'coconut',
#        'pomegranate', 'papaya', 'coffee', 'chickpea', 'jute', 'chickpea',
#        'maize', 'lentil', 'pomegranate', 'coffee', 'mungbean',
#        'watermelon', 'watermelon', 'cotton', 'mango', 'blackgram',
#        'mungbean', 'pomegranate', 'banana', 'coffee', 'muskmelon',
#        'chickpea', 'grapes', 'apple', 'jute', 'grapes', 'mango', 'orange',
# ...

# %%
classifier.predict([[24,190,234,33.5445,80.1234,7.8977,40.566]]) #25	129	195	17.986678	81.177121	5.777271	72.371277
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['grapes'], dtype=object)

# %%
classifier.predict([[56,116,200,22.345343,89.65633,9.78634343,90.8343436]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['apple'], dtype=object)

# %%
classifier.predict([[25,129,195,17.986678,81.177121,5.777271,72.371277]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['grapes'], dtype=object)

# %% [markdown]
# ### Linear regression

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label
# 0     202.935536    rice
# 1     226.655537    rice
# ...

# %%
df['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
df['label'].replace({'rice'  : '1',
'maize'      :    '2',
'jute'        :   '3',
'cotton'       :  '4',
'coconut'       : '5',
'papaya'         :'6',
'orange'         :'7',
'apple'          :'8',
'muskmelon'     : '9',
'watermelon'    : '10',
'grapes'       :  '11',
'mango'         : '12',
'banana'         :'13',
'pomegranate'   : '14',
'lentil'        : '15',
'blackgram'     : '16',
'mungbean'      : '17',
'mothbeans'     : '18',
'pigeonpeas'    : '19',
'kidneybeans'    :'20',
'chickpea'     :  '21',
'coffee':'22'},inplace=True)

# %%
df
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall label
# 0     202.935536     1
# 1     226.655537     1
# 2     263.964248     1
# ...

# %% [markdown]
# #### spliting data

# %%
x1=df[['Nitrogen','phosphorus','potassium','temperature','humidity','ph','rainfall']]

# %%
x1
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall
# 0     202.935536
# 1     226.655537
# 2     263.964248
# 3     242.864034
# ...

# %%
y1=df['label'].values

# %%
y1
# Out:
# array(['1', '1', '1', ..., '22', '22', '22'], dtype=object)

# %% [markdown]
# ##### training and testing data set

# %%
from sklearn.model_selection import train_test_split

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2)

# %%
x1_train
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 1359        81           6         55    24.889105  85.870591  6.110143
# 778         29          67         21    29.791811  63.387892  6.621324
# 1248         8         127        196    27.027661  83.170939  5.833302
# 193         87          48         25    18.653967  61.378797  6.656730
# 951         29          21         45    23.409815  93.132770  6.749260
# ...        ...         ...        ...          ...        ...       ...
# 1431       110          25         54    28.911056  90.784138  6.425931
# 402         33          73         23    29.235405  59.389676  5.985793
# 840          5          65         19    18.280722  68.103654  6.978362
# 335         33          59         22    22.642369  21.593961  5.947000
# 13          93          56         36    24.014976  82.056872  6.984354
#
#         rainfall
# 1359   51.706991
# 778    63.021699
# 1248   70.956660
# 193    93.620392
# ...

# %%
x1_test
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 176         74          39         23    22.626511  65.774729  6.780736
# 1086       100          74         52    25.434805  81.539778  5.837258
# 792         29          63         17    30.026299  67.888116  7.261543
# 1239        20         122        204    11.797647  80.863254  6.487370
# 547         10          44         24    30.992569  43.021514  8.034413
# ...        ...         ...        ...          ...        ...       ...
# 902          8          26         36    18.783596  87.402477  6.804781
# 2031        81          36         38    23.765547  87.983299  6.334838
# 853         32          79         22    27.601955  63.461707  5.916454
# 2034        65          39         45    23.668054  70.890007  6.768001
# 1173         9          38         25    34.585615  50.340353  5.497947
#
#         rainfall
# 176    88.172510
# 1086   96.478004
# 792    66.472646
# 1239   65.069625
# ...

# %%
y1_train
# Out:
# array(['10', '16', '11', ..., '15', '20', '1'], dtype=object)

# %%
y1_test
# Out:
# array(['2', '13', '16', '11', '18', '6', '13', '20', '9', '16', '12',
#        '21', '17', '21', '8', '10', '11', '3', '12', '15', '18', '21',
#        '11', '16', '16', '15', '8', '22', '17', '6', '7', '6', '12', '8',
#        '19', '21', '9', '17', '18', '22', '4', '15', '15', '9', '19',
#        '20', '6', '6', '14', '4', '6', '13', '18', '5', '19', '8', '16',
#        '1', '13', '9', '5', '5', '10', '17', '19', '22', '17', '19', '13',
#        '5', '6', '11', '18', '8', '9', '5', '10', '13', '7', '13', '12',
#        '15', '6', '5', '5', '20', '9', '22', '15', '9', '22', '5', '16',
#        '1', '14', '10', '15', '1', '20', '21', '7', '5', '17', '19', '20',
#        '12', '10', '17', '13', '8', '5', '18', '15', '8', '6', '7', '2',
#        '14', '14', '3', '4', '11', '10', '19', '14', '13', '22', '20',
#        '13', '18', '1', '8', '4', '8', '8', '4', '22', '15', '3', '11',
#        '5', '22', '8', '9', '17', '7', '1', '19', '4', '6', '2', '7',
# ...

# %% [markdown]
# ### linear regression algorithm

# %%
from sklearn.linear_model import LogisticRegression     #from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg1=lg.fit(x1_train,y1_train)
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lg1
# Out:
# LogisticRegression()

# %%
lg1.predict(x1_test)
# Out:
# array(['2', '13', '16', '11', '18', '6', '13', '20', '9', '16', '12',
#        '21', '17', '21', '8', '10', '11', '3', '12', '15', '18', '21',
#        '11', '16', '16', '15', '8', '22', '17', '6', '7', '6', '12', '8',
#        '19', '21', '9', '17', '17', '22', '4', '15', '15', '9', '19',
#        '20', '3', '9', '14', '4', '6', '13', '16', '5', '19', '8', '16',
#        '1', '13', '9', '5', '5', '10', '17', '19', '22', '17', '19', '13',
#        '5', '12', '11', '18', '8', '9', '5', '10', '13', '7', '13', '12',
#        '15', '6', '5', '5', '19', '9', '22', '15', '9', '22', '5', '18',
#        '1', '14', '10', '15', '1', '20', '21', '7', '5', '17', '19', '20',
#        '12', '10', '17', '13', '8', '5', '18', '15', '8', '6', '7', '4',
#        '14', '14', '3', '4', '11', '10', '19', '14', '13', '22', '20',
#        '13', '18', '1', '8', '4', '8', '8', '4', '22', '15', '3', '11',
#        '5', '22', '8', '9', '17', '7', '3', '19', '4', '6', '2', '7',
# ...

# %%
C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
  warnings.warn(lg1.predict([[23,39,22,29.256493,81.979522,6.864839,42.024833]])
# Out:
#   Cell In[78], line 1
#     C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
lg1.predict([[23,39,22,29.256493,81.979522,6.864839,42.024833]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['17'], dtype=object)

# %%
lg1.score(x1_test,y1_test)
# Out:
# 0.925

# %% [markdown]
# ### Naive Bayes Classifiers

# %%
from sklearn.naive_bayes import GaussianNB    #from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb.fit(x1_train,y1_train)
# Out:
# GaussianNB()

# %%
nb.predict(x1_test)
# Out:
# array(['2', '13', '16', '11', '18', '6', '13', '20', '9', '16', '12',
#        '21', '17', '21', '8', '10', '11', '3', '12', '15', '18', '21',
#        '11', '16', '16', '15', '8', '22', '17', '6', '7', '6', '12', '8',
#        '19', '21', '9', '17', '18', '22', '4', '15', '15', '9', '19',
#        '20', '6', '6', '14', '4', '6', '13', '18', '5', '19', '8', '16',
#        '1', '13', '9', '5', '5', '10', '17', '19', '22', '17', '19', '13',
#        '5', '6', '11', '18', '8', '9', '5', '10', '13', '7', '13', '12',
#        '15', '6', '5', '5', '20', '9', '22', '15', '9', '22', '5', '16',
#        '1', '14', '10', '15', '1', '20', '21', '7', '5', '17', '19', '20',
#        '12', '10', '17', '13', '8', '5', '18', '15', '8', '6', '7', '4',
#        '14', '14', '3', '4', '11', '10', '19', '14', '13', '22', '20',
#        '13', '18', '1', '8', '4', '8', '8', '4', '22', '15', '3', '11',
#        '5', '22', '8', '9', '17', '7', '3', '19', '4', '6', '2', '7',
# ...

# %%
nb.predict([[78,50,45,67.9343443,51.324424,8.5252532,32.353422]])   #23,39,22,29.256493,81.979522,6.864839,42.024833]])
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['19'], dtype='<U2')

# %%
nb.score(x1_test,y1_test)
# Out:
# 0.990909090909091

# %% [markdown]
# ### kmeans-clustering

# %%
df.head()
# Out:
#    Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      rainfall label
# 0  202.935536     1
# 1  226.655537     1
# 2  263.964248     1
# 3  242.864034     1
# 4  262.717340     1

# %%
sns.pairplot(data=df,hue='label')

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range (1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [18908720.463645894,
#  12158586.35353351,
#  7505846.980436154,
#  5402409.884036783,
#  4476564.709189798,
#  3807278.129332443,
#  3154814.1072497987,
#  2773866.181388656,
#  2415828.400226353,
#  2174607.6059353612]

# %%
plt.plot(1,11,wcss)

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=3)
y_means=km.fit_predict(X)
# Out:
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Ashutosh Rawat\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(

# %%
y_means
# Out:
# array([2, 2, 2, ..., 2, 0, 2])

# %%
X[y_means==0]
# Out:
# array([[71, 54, 16, ..., 5.7499144210000015, 87.75953857, '2'],
#        [61, 44, 17, ..., 6.931756557999999, 102.2662445, '2'],
#        [80, 43, 16, ..., 6.657964753, 66.71995467, '2'],
#        ...,
#        [103, 33, 33, ..., 7.131435858, 126.8073984, '22'],
#        [99, 15, 27, ..., 6.086922359, 127.92461000000002, '22'],
#        [117, 32, 34, ..., 6.758792552, 127.1752928, '22']], dtype=object)

# %%
X[y_means==1]
# Out:
# array([[24, 130, 195, ..., 6.112305667, 67.12534492, '11'],
#        [13, 144, 204, ..., 6.092241627000001, 68.38135469, '11'],
#        [22, 123, 205, ..., 5.896343436, 68.73932528, '11'],
#        ...,
#        [31, 137, 196, ..., 6.400321212000001, 120.6310784, '8'],
#        [36, 144, 196, ..., 6.496934492, 115.3611268, '8'],
#        [10, 140, 197, ..., 6.229498836, 124.4683112, '8']], dtype=object)

# %%
X[y_means==2]
# Out:
# array([[90, 42, 43, ..., 6.502985292000001, 202.9355362, '1'],
#        [85, 58, 41, ..., 7.038096361, 226.6555374, '1'],
#        [60, 55, 44, ..., 7.840207144, 263.9642476, '1'],
#        ...,
#        [107, 34, 32, ..., 6.78006386, 177.7745075, '22'],
#        [118, 33, 30, ..., 6.362607851, 173.32283859999995, '22'],
#        [104, 18, 30, ..., 6.779832611000002, 140.9370415, '22']],
#       dtype=object)

# %%
plt.scatter(X[y_means==0,0],X[y_means==0,1],color='blue')
plt.scatter(X[y_means==1,0],X[y_means==1,1],color='red')
plt.scatter(X[y_means==2,0],X[y_means==2,1],color='yellow')

# %%
km.score(X)
# Out:
# -7505846.980436153
